# %%
Hardware refers to the physical components of a computer that you can touch, such as a keyboard or monitor, while software consists of programs that run on the hardware. Hardware is like the body, and software is like the brain.
For example, when you type on a keyboard (hardware), the words appear on the screen because of software like Microsoft Word.
