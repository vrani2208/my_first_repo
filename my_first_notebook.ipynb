# %%
Hardware refers to the physical components of a computer that you can touch, such as a keyboard or monitor.
Software is a set of instructions or programs that run on the hardware, like an operating system or applications.
Hardware is like the body,Software is like the brain
When you type on a keyboard (hardware), the word appears on screen because of software like microsoft word.
